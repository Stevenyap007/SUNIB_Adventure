# %%
# %pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

# Fetch dataset
heart_disease = fetch_ucirepo(id=45)

# Extract features and target
X = heart_disease.data.features
y = heart_disease.data.targets

# Save to CSV
X.to_csv("heart_disease_features.csv", index=False)
y.to_csv("heart_disease_targets.csv", index=False)

# %%
features_path = "heart_disease_features.csv"
targets_path = "heart_disease_targets.csv"

features_df = pd.read_csv(features_path)
targets_df = pd.read_csv(targets_path)

# Display basic info of the datasets
features_df.info(), targets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
# dtypes: float64(3), int64(10)
# memory usage: 30.9 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   num     303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB
# (None, None)

# %%
print(features_df.isnull().sum())  # Check missing values in features
print(targets_df.isnull().sum())  # Check missing values in target
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# dtype: int64
# num    0
# dtype: int64

# %%
features_df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope   ca  thal
# 0        3  0.0   6.0
# 1        2  3.0   3.0
# 2        2  2.0   7.0
# 3        3  0.0   3.0
# 4        1  0.0   3.0
# ..     ...  ...   ...
# 298      2  0.0   7.0
# 299      2  2.0   7.0
# 300      2  1.0   7.0
# 301      2  1.0   3.0
# 302      1  NaN   3.0
#
# [303 rows x 13 columns]

# %%
targets_df
# Out:
#      num
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# ..   ...
# 298    1
# 299    2
# 300    3
# 301    1
# 302    0
#
# [303 rows x 1 columns]

# %%
targets_df[('num')].value_counts()
# Out:
# num
# 0    164
# 1     55
# 2     36
# 3     35
# 4     13
# Name: count, dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np

# Handling missing values using mean imputation
imputer = SimpleImputer(strategy="mean")
features_df.iloc[:, :] = imputer.fit_transform(features_df)

# Normalize numerical features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features_df)

# Convert target to binary classification (assuming 0 = no disease, 1 = disease)
targets = np.where(targets_df.values.flatten() > 0, 1, 0)

# Split data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(features_scaled, targets, test_size=0.2, random_state=42)


X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((242, 13), (61, 13), (242,), (61,))

# %% [markdown]
# # ANN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

def create_ann(hidden_layers=[16, 8], activation='relu', optimizer='adam', learning_rate=0.001):
    model = keras.Sequential()

    model.add(layers.Dense(hidden_layers[0], activation=activation, input_shape=(X_train.shape[1],)))

    for nodes in hidden_layers[1:]:
        model.add(layers.Dense(nodes, activation=activation))

    model.add(layers.Dense(1, activation='sigmoid'))

    if optimizer == 'adam':
        opt = keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        opt = keras.optimizers.SGD(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = keras.optimizers.RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Choose from: 'adam', 'sgd', 'rmsprop'.")

    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

ann_model = create_ann(hidden_layers=[32, 16], activation='relu', optimizer='adam', learning_rate=0.001)
history = ann_model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# Evaluate model performance
test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.5076 - loss: 0.8521 - val_accuracy: 0.4754 - val_loss: 0.7912
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5256 - loss: 0.7135 - val_accuracy: 0.5738 - val_loss: 0.6852
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6784 - loss: 0.6168 - val_accuracy: 0.6230 - val_loss: 0.6061
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7558 - loss: 0.5532 - val_accuracy: 0.7377 - val_loss: 0.5473
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8246 - loss: 0.4966 - val_accuracy: 0.8197 - val_loss: 0.4978
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7752 - loss: 0.4986 - val_accuracy: 0.8361 - val_loss: 0.4562
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7598 - loss: 0.4698 - val_accuracy: 0.8361 - val_loss: 0.4236
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8380 - loss: 0.4118 - val_accuracy: 0.8525 - val_loss: 0.3995
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8587 - loss: 0.3815 - val_accuracy: 0.8689 - val_loss: 0.3821
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8007 - loss: 0.4191 - val_accuracy: 0.8525 - val_loss: 0.3769
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8192 - loss: 0.4247 - val_accuracy: 0.8525 - val_loss: 0.3726
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8229 - loss: 0.3681 - val_accuracy: 0.8525 - val_loss: 0.3677
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8446 - loss: 0.3521 - val_accuracy: 0.8689 - val_loss: 0.3639
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8577 - loss: 0.3203 - val_accuracy: 0.8689 - val_loss: 0.3617
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8468 - loss: 0.3419 - val_accuracy: 0.8689 - val_loss: 0.3592
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8492 - loss: 0.3536 - val_accuracy: 0.8689 - val_loss: 0.3564
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8689 - loss: 0.3132 - val_accuracy: 0.8689 - val_loss: 0.3558
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8592 - loss: 0.3136 - val_accuracy: 0.8689 - val_loss: 0.3576
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8512 - loss: 0.3118 - val_accuracy: 0.8689 - val_loss: 0.3560
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8895 - loss: 0.2542 - val_accuracy: 0.8689 - val_loss: 0.3568
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8733 - loss: 0.2950 - val_accuracy: 0.8689 - val_loss: 0.3575
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8574 - loss: 0.3012 - val_accuracy: 0.8689 - val_loss: 0.3586
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8889 - loss: 0.2666 - val_accuracy: 0.8852 - val_loss: 0.3587
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9113 - loss: 0.2411 - val_accuracy: 0.8852 - val_loss: 0.3604
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8461 - loss: 0.3000 - val_accuracy: 0.8525 - val_loss: 0.3634
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8640 - loss: 0.2937 - val_accuracy: 0.8689 - val_loss: 0.3635
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9086 - loss: 0.2497 - val_accuracy: 0.8689 - val_loss: 0.3683
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8552 - loss: 0.3078 - val_accuracy: 0.8689 - val_loss: 0.3714
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8835 - loss: 0.2615 - val_accuracy: 0.8689 - val_loss: 0.3701
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8666 - loss: 0.2724 - val_accuracy: 0.8689 - val_loss: 0.3669
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8933 - loss: 0.2234 - val_accuracy: 0.8689 - val_loss: 0.3689
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9023 - loss: 0.2329 - val_accuracy: 0.8689 - val_loss: 0.3704
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8866 - loss: 0.2587 - val_accuracy: 0.8689 - val_loss: 0.3740
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9099 - loss: 0.2581 - val_accuracy: 0.8689 - val_loss: 0.3776
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8851 - loss: 0.2496 - val_accuracy: 0.8689 - val_loss: 0.3780
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9079 - loss: 0.2356 - val_accuracy: 0.8689 - val_loss: 0.3913
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9003 - loss: 0.2533 - val_accuracy: 0.8689 - val_loss: 0.3919
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9015 - loss: 0.2438 - val_accuracy: 0.8689 - val_loss: 0.3953
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8857 - loss: 0.2645 - val_accuracy: 0.8689 - val_loss: 0.3970
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9134 - loss: 0.2177 - val_accuracy: 0.8689 - val_loss: 0.4022
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9374 - loss: 0.1963 - val_accuracy: 0.8689 - val_loss: 0.4005
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9146 - loss: 0.2290 - val_accuracy: 0.8689 - val_loss: 0.3986
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9243 - loss: 0.2072 - val_accuracy: 0.8689 - val_loss: 0.4058
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9260 - loss: 0.2217 - val_accuracy: 0.8689 - val_loss: 0.4063
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9156 - loss: 0.2342 - val_accuracy: 0.8689 - val_loss: 0.4179
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9262 - loss: 0.1999 - val_accuracy: 0.8689 - val_loss: 0.4170
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9337 - loss: 0.1888 - val_accuracy: 0.8689 - val_loss: 0.4105
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9347 - loss: 0.2186 - val_accuracy: 0.8689 - val_loss: 0.4166
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9319 - loss: 0.1972 - val_accuracy: 0.8689 - val_loss: 0.4235
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9372 - loss: 0.1997 - val_accuracy: 0.8689 - val_loss: 0.4277
# Test Accuracy: 0.8689

# %% [markdown]
# # Define a Tuning Function

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

def create_ann(hidden_layers=[32, 16], activation='relu', optimizer='adam', learning_rate=0.001):
    model = keras.Sequential()

    model.add(layers.Dense(hidden_layers[0], activation=activation, input_shape=(X_train.shape[1],)))

    for nodes in hidden_layers[1:]:
        model.add(layers.Dense(nodes, activation=activation))

    model.add(layers.Dense(1, activation='sigmoid'))

    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        opt = SGD(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Choose from: 'adam', 'sgd', 'rmsprop'.")

    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Define Different Hyperparameter Values for Tuning

# %%
hidden_layer_options = [[32, 16], [64, 32, 16], [128, 64, 32]]
activation_options = ['relu', 'tanh', 'sigmoid']
optimizer_options = ['adam', 'sgd', 'rmsprop']
learning_rate_options = [0.01, 0.001, 0.0005]

# %% [markdown]
# # Run Hyperparameter Tuning (Grid Search)

# %%
from itertools import product

best_accuracy = 0
best_config = {}

for hidden_layers, activation, optimizer, learning_rate in product(hidden_layer_options, activation_options, optimizer_options, learning_rate_options):

    print(f"Testing Configuration: Layers {hidden_layers}, Activation {activation}, Optimizer {optimizer}, Learning Rate {learning_rate}")

    ann_model = create_ann(hidden_layers=hidden_layers, activation=activation, optimizer=optimizer, learning_rate=learning_rate)

    history = ann_model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=0)

    test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)

    print(f"Test Accuracy: {test_accuracy:.4f}")

    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_config = {
            "hidden_layers": hidden_layers,
            "activation": activation,
            "optimizer": optimizer,
            "learning_rate": learning_rate
        }

print("\n Best Configuration Found:")
print(best_config)
print(f"Best Test Accuracy: {best_accuracy:.4f}")
# Out:
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7541
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.8361
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8197
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7705
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.5246
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.9016
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8689
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.9016
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.5574
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4590
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8852
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8033
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8197
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8852
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7869
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4754
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.7705
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8197
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8197
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.9016
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.8361
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.9180
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8361
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.4754
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.5246
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8525
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8852
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8197
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8197
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8197
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7049
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.5738
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8033
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8033
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.9016
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.8197
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.9180
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8852
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8852
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.4754
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.5246
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8689
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
#
# 🎯 Best Configuration Found:
# {'hidden_layers': [64, 32, 16], 'activation': 'tanh', 'optimizer': 'rmsprop', 'learning_rate': 0.001}
# Best Test Accuracy: 0.9180

# %%
import pandas as pd
from itertools import product

results = []

best_accuracy = 0
best_config = {}

for hidden_layers, activation, optimizer, learning_rate in product(hidden_layer_options, activation_options, optimizer_options, learning_rate_options):

    print(f"Testing Configuration: Layers {hidden_layers}, Activation {activation}, Optimizer {optimizer}, Learning Rate {learning_rate}")

    ann_model = create_ann(hidden_layers=hidden_layers, activation=activation, optimizer=optimizer, learning_rate=learning_rate)

    history = ann_model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=0)

    test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)

    results.append({
        "hidden_layers": str(hidden_layers),
        "activation": activation,
        "optimizer": optimizer,
        "learning_rate": learning_rate,
        "test_accuracy": test_accuracy
    })

    print(f"Test Accuracy: {test_accuracy:.4f}\n")

    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_config = {
            "hidden_layers": hidden_layers,
            "activation": activation,
            "optimizer": optimizer,
            "learning_rate": learning_rate
        }

results_df = pd.DataFrame(results)

results_csv_path = "ann_tuning_results.csv"
results_df.to_csv(results_csv_path, index=False)

print("\n Best Configuration Found:")
print(best_config)
print(f" Best Test Accuracy: {best_accuracy:.4f}")
# Out:
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.01
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.5410
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.7541
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.9016
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.6557
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.6066
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8197
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8197
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7869
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4918
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [64, 32, 16], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8197
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.9016
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.8361
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.8361
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8197
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.7705
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [64, 32, 16], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8852
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.7377
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.7213
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.7705
#
# Testing Configuration: Layers [128, 64, 32], Activation relu, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8361
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8033
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.9344
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [128, 64, 32], Activation tanh, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.9016
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.01
# Test Accuracy: 0.8525
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer adam, Learning Rate 0.0005
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.01
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.001
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer sgd, Learning Rate 0.0005
# Test Accuracy: 0.4754
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.01
# Test Accuracy: 0.8197
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.001
# Test Accuracy: 0.8689
#
# Testing Configuration: Layers [128, 64, 32], Activation sigmoid, Optimizer rmsprop, Learning Rate 0.0005
# Test Accuracy: 0.8852
#
#
#  Best Configuration Found:
# {'hidden_layers': [128, 64, 32], 'activation': 'tanh', 'optimizer': 'rmsprop', 'learning_rate': 0.01}
#  Best Test Accuracy: 0.9344

# %% [markdown]
# Hasil test accuracy yang didapatkan bervariasi antara 47%-93% dengan rata rata 81%
# Konfigurasi terbaik didapatkan dengan kombinasi:
# {'hidden_layers': [128, 64, 32], 'activation': 'tanh', 'optimizer': 'rmsprop', 'learning_rate': 0.01}
#  Best Test Accuracy: 0.9344
#
# Dengan melihat beberapa tes lainya paramater yang konsisten terhadap performa model adalah activation tanh, sementara parameter lainnya seperti optimizer masih dapat berubah antara rmsprop dan adam.

# %% [markdown]
# # Evaluation of Best Model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
best_ann_model = create_ann(hidden_layers=[128, 64, 32], activation='tanh', optimizer='rmsprop', learning_rate=0.01)

best_ann_model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test), verbose=0)

y_pred_probs = best_ann_model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Best Model Evaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Best Model Evaluation Metrics:
# Accuracy: 0.9344
# Precision: 0.9118
# Recall: 0.9688
# F1 Score: 0.9394

# %% [markdown]
# # Save the best model

# %%
best_ann_model.save("best_heart_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
